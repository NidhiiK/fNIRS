# %%
import pandas as pd

# %%
# df1 = [pd.read_csv('./raw_data/raw_data/sub_'+str(no)+'/fnirs_init.csv') for no in range(1, 98)]

# %%
df1 = [pd.read_csv('./raw_data/raw_data/sub_'+str(no)+'/fnirs_init.csv') for no in ['1',  '5', '7', '13', '14', '15', '20', '21', '22', '23', '24', '25', '27', '28', '29', '31', '32', '34', '35', '36', '37', '38', '40', '42', '43', '44', '45', '46', '47', '48', '49', '51', '52', '54', '55', '56', '57', '58', '60', '61', '62', '63', '64', '65', '68', '69', '70', '71', '72', '73', '74', '75', '76', '78', '79', '80', '81', '82', '83', '84', '85', '86', '91', '92', '93', '94', '95', '97']]

# %%
df1[34]
# Out:
#      row_index      timestamp  label        T   AC-A1  AC-A2  AC-A21  AC-A22  \
# 0         1043  1622304171496     -1  200.297  2647.0  225.1  5233.0   474.9
# 1         1044  1622304171563     -1  200.489  2662.0  226.2  5265.0   482.9
# 2         1045  1622304171629     -1  200.681  2691.0  231.8  5274.0   485.0
# 3         1046  1622304171695     -1  200.873  2671.0  230.2  5251.0   472.9
# 4         1047  1622304171761     -1  201.065  2658.0  225.0  5246.0   477.2
# ..         ...            ...    ...      ...     ...    ...     ...     ...
# 100       1143  1622304190428     -1  219.484  2474.0  223.5  5066.0   476.5
# 101       1144  1622304190494     -1  219.676  2478.0  227.5  5091.0   479.7
# 102       1145  1622304190560     -1  219.868  2505.0  232.6  5112.0   485.1
# 103       1146  1622304190626     -1  220.060  2528.0  238.5  5089.0   479.4
# 104       1147  1622304190692     -1  220.252  2466.0  227.9  5046.0   475.4
#
# ...

# %%
'1',  '5', '7', '13', '14', '15', '20', '21', '22', '23', '24', '25', '27', '28', '29', '31', '32', '34', '35', '36', '37', '38', '40', '42', '43', '44', '45', '46', '47', '48', '49', '51', '52', '54', '55', '56', '57', '58', '60', '61', '62', '63', '64', '65', '68', '69', '70', '71', '72', '73', '74', '75', '76', '78', '79', '80', '81', '82', '83', '84', '85', '86', '91', '92', '93', '94', '95', '97'
# Out:
# ('1',
#  '5',
#  '7',
#  '13',
#  '14',
#  '15',
#  '20',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '27',
#  '28',
#  '29',
#  '31',
#  '32',
#  '34',
#  '35',
#  '36',
#  '37',
#  '38',
#  '40',
#  '42',
#  '43',
#  '44',
#  '45',
#  '46',
#  '47',
#  '48',
#  '49',
#  '51',
#  '52',
#  '54',
#  '55',
#  '56',
#  '57',
#  '58',
#  '60',
#  '61',
#  '62',
#  '63',
#  '64',
#  '65',
#  '68',
#  '69',
#  '70',
#  '71',
#  '72',
#  '73',
#  '74',
#  '75',
#  '76',
#  '78',
#  '79',
#  '80',
#  '81',
#  '82',
#  '83',
#  '84',
#  '85',
#  '86',
#  '91',
#  '92',
#  '93',
#  '94',
#  '95',
#  '97')

# %%
data1 = pd.concat(df1, axis=0).sample(frac=1.0, random_state=123).reset_index(drop=True)

# %%
data1
# Out:
#       row_index      timestamp  label          T   AC-A1   AC-A2  AC-A21  \
# 0          1795  1624547768000     -1    344.707  2648.0   117.8  5249.0
# 1          4659  1618860824517     -1   3939.583  2723.0   418.4  5277.0
# 2          2086  1612805693353     -1    241.957  8873.0  4660.0  9974.0
# 3          1809  1625077703541     -1    347.409  3743.0   348.5  5354.0
# 4          2030  1621277612031     -1  11558.890  2665.0   371.1  6268.0
# ...         ...            ...    ...        ...     ...     ...     ...
# 7147       1160  1623951999942     -1   8384.289  2274.0   193.6  4488.0
# 7148       1672  1622735898292     -1    321.103  3830.0   391.7  4164.0
# 7149       2049  1614095843961     -1   1696.543  4022.0   716.4  6367.0
# 7150       2803  1621869973317     -1    539.880  3062.0   309.4  5961.0
# 7151       2392  1622133447520     -1   2324.995  3785.0   254.5  6097.0
#
#       AC-A22   PH-A1   PH-A2  ...  PH-C23  PH-C24   AC-D3   AC-D4  AC-D23  \
# ...

# %%
df2 = [pd.read_csv('./raw_data/raw_data/sub_'+str(no)+'/fnirs_test.csv') for no in ['1',  '5', '7', '13', '14', '15', '20', '21', '22', '23', '24', '25', '27', '28', '29', '31', '32', '34', '35', '36', '37', '38', '40', '42', '43', '44', '45', '46', '47', '48', '49', '51', '52', '54', '55', '56', '57', '58', '60', '61', '62', '63', '64', '65', '68', '69', '70', '71', '72', '73', '74', '75', '76', '78', '79', '80', '81', '82', '83', '84', '85', '86', '91', '92', '93', '94', '95', '97']]

# %%
df2[4]
# Out:
#       row_index      timestamp  label         T   AC-A1  AC-A2  AC-A21  \
# 0             0  1611091095938     -1  2261.592  2374.0  519.8  6533.0
# 1             1  1611091096006     -1  2261.784  2413.0  532.0  6588.0
# 2             2  1611091096085     -1  2261.976  2443.0  547.3  6461.0
# 3             3  1611091096141     -1  2262.168  2379.0  521.6  6465.0
# 4             4  1611091096217     -1  2262.360  2352.0  512.2  6479.0
# ...         ...            ...    ...       ...     ...    ...     ...
# 3054       3054  1611091682055      2  2848.089  2382.0  495.6  6054.0
# 3055       3055  1611091682122      2  2848.281  2304.0  470.6  6019.0
# 3056       3056  1611091682188      2  2848.473  2300.0  463.0  5988.0
# 3057       3057  1611091682255      2  2848.665  2339.0  471.4  5999.0
# 3058       3058  1611091682322      2  2848.857  2364.0  486.2  5993.0
#
#       AC-A22  PH-A1  PH-A2  ...  PH-C23  PH-C24  AC-D3   AC-D4  AC-D23  \
# ...

# %%
data2 = pd.concat(df2, axis=0).sample(frac=1.0, random_state=123).reset_index(drop=True)

# %%
data2
# Out:
#         row_index      timestamp  label          T   AC-A1  AC-A2  AC-A21  \
# 0            2223  1613423551213      1   3336.920  2164.0  469.2  6017.0
# 1            2978  1611436455708     -1   2738.926  4509.0  531.5  6685.0
# 2            1495  1617313476890     -1   7509.196  1984.0  215.6  4263.0
# 3            2389  1612820928579      2   3185.933  2240.0  135.4  4901.0
# 4            1329  1626276316002      0   2561.651  3764.0  223.6  5119.0
# ...           ...            ...    ...        ...     ...    ...     ...
# 211284        955  1622738041744     -1   2464.662  3115.0  382.0  2579.0
# 211285       2846  1625163688330     -1   2515.967  2969.0  167.4  3036.0
# 211286       2305  1611436326640      1   2609.704  4612.0  531.4  6785.0
# 211287        293  1612990397630      3  15639.620  2057.0  224.9  5204.0
# 211288        300  1611435941184      3   2224.654  4333.0  507.4  6126.0
#
#         AC-A22  PH-A1  PH-A2  ...  PH-C23  PH-C24   AC-D3   AC-D4  AC-D23  \
# ...

# %%
data1['label'].value_counts()
# Out:
# -1    7152
# Name: label, dtype: int64

# %%
data2['label'].value_counts()
# Out:
# -1    54108
#  3    43652
#  2    40144
#  0    36700
#  1    36685
# Name: label, dtype: int64

# %%
data1.describe()
# Out:
#          row_index     timestamp   label             T        AC-A1  \
# count  7152.000000  7.152000e+03  7152.0   7152.000000  7152.000000
# mean   2165.738395  1.620200e+12    -1.0   2753.503408  3085.056306
# std    1511.639675  5.434540e+09     0.0   4620.000250  1470.109880
# min     103.000000  1.605027e+12    -1.0    158.440000   924.000000
# 25%    1146.000000  1.615657e+12    -1.0    312.019000  2153.000000
# 50%    1676.000000  1.622133e+12    -1.0    571.800000  2649.000000
# 75%    2606.000000  1.624042e+12    -1.0   2071.629000  3872.000000
# max    7556.000000  1.627060e+12    -1.0  19584.790000  9709.000000
#
#              AC-A2        AC-A21        AC-A22        PH-A1        PH-A2  ...  \
# count  7152.000000   7152.000000   7152.000000  7152.000000  7152.000000  ...
# mean    439.607665   5352.691415    865.321546   183.417371   187.771363  ...
# std     574.903398   1217.596941   1213.660111    79.636728    79.350804  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(data2)
# Out:
# StandardScaler()

# %%
data2.describe()
